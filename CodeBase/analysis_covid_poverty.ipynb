# %% [markdown]
# # Lower Versus Higher Poverty Counties
# ---
# In this section, determine if there are any differences in CoVID infection and vaccination rates between a lower and higher poverty counties in the US?

# %%
# Set up dependencies
import pandas as pd
import numpy as np

# Set up the DF for cleaned covid dataset
df_cleaned_covid = pd.read_csv('../Outputs/cleaned_covid_counties.csv')

df_cleaned_covid.head()
# Out:
#   state                      county  population  total cases  total deaths  \
# 0    AK      Aleutians East Borough        3337          812             0
# 1    AK  Aleutians West Census Area        5634         1174             0
# 2    AK      Anchorage Municipality      288000       121792           284
# 3    AK          Bethel Census Area       18386        13328             0
# 4    AK         Bristol Bay Borough         836            0             0
#
#    hospital beds  hospital beds usage  hospital beds covid  hospital icu beds  \
# 0            NaN                  NaN                  NaN                NaN
# 1            NaN                  NaN                  NaN                NaN
# 2          559.0                486.0                 12.0               60.0
# 3            NaN                  NaN                  NaN                NaN
# 4            NaN                  NaN                  NaN                NaN
#
# ...
