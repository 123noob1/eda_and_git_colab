# %%
# Setup dependencies
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# %%
csv_covid_counties = '../Outputs/cleaned_covid_counties.csv'
covid_counties = pd.read_csv(csv_covid_counties)
#covid_counties

# %%
#Q2 Which states have the highest vaccination and infection rates?

# %%
#vaccination completed
#total cases

# %%
grouped_df = covid_counties.groupby('state').agg({'population': 'sum', 'total cases': 'sum', 'vaccination completed': 'sum'}).reset_index()
grouped_df.head()
# Out:
#   state  population  total cases  vaccination completed
# 0    AK      731545       297407               464153.0
# 1    AL     4903185      1658639              2417598.0
# 2    AR     3017804       994317              1584830.0
# 3    AZ     7278717      2471556              4668433.0
# 4    CA    39512223     12240589             28724394.0

# %%
grouped_df['covid_cases_%'] = (grouped_df['total cases'] / grouped_df['population'] * 100).round(2)
grouped_df['vaccinated_pop_%'] = (grouped_df['vaccination completed'] / grouped_df['population'] *100).round(2)

# %%
#grouped_df

# %%
grouped_df = grouped_df.sort_values(['covid_cases_%'], ascending=False)
grouped_df.head()
# Out:
#    state  population  total cases  vaccination completed  covid_cases_%  \
# 0     AK      731545       297407               464153.0          40.65
# 41    RI     1059361       426947               820172.0          40.30
# 29    ND      762062       290693               415832.0          38.15
# 17    KY     4467673      1687705              2511980.0          37.78
# 51    WV     1792147       650365              1040252.0          36.29
#
#     vaccinated_pop_%
# 0              63.45
# 41             77.42
# 29             54.57
# 17             56.23
# 51             58.05

# %%
grouped_df = grouped_df.sort_values(['vaccinated_pop_%'], ascending=True)
grouped_df.head()
# Out:
#    state  population  total cases  vaccination completed  covid_cases_%  \
# 25    MP       53600        13395                    0.0          24.99
# 7     DC      705749       178904                    0.0          25.35
# 31    NH     1359711       379433                    0.0          27.91
# 1     AL     4903185      1658639              2417598.0          33.83
# 10    GA    10617423      2976769              5382631.0          28.04
#
#     vaccinated_pop_%
# 25              0.00
# 7               0.00
# 31              0.00
# 1              49.31
# 10             50.70

# %%
slope, intc, r, p, std_err = linregress(grouped_df['covid_cases_%'], grouped_df['vaccinated_pop_%'])
model=slope*grouped_df["covid_cases_%"]+intc
plt.scatter(grouped_df["covid_cases_%"], grouped_df["vaccinated_pop_%"])
plt.plot(grouped_df["covid_cases_%"], model, color='red')
print(str("r value: ") + str(r.round(2)))
print(str("p value: ")+ str(p.round(2)))
print("regression equation: y="+str(slope.round(2))+"*x+"+str(intc.round(2)))
plt.xlabel("Covid Cases (%)")
plt.ylabel("Vaccinated Population (%)")
plt.savefig("covid_vaccination_regression.png")
# Out:
# r value: 0.1
# p value: 0.47
# regression equation: y=0.43*x+47.54

# %%
#we dropped the three states which we assume had missing data
grouped_df_min_3 = grouped_df[grouped_df['vaccination completed'] != 0]

# %%
slope, intc, r, p, std_err = linregress(grouped_df_min_3['covid_cases_%'], grouped_df_min_3['vaccinated_pop_%'])
model=slope*grouped_df_min_3["covid_cases_%"]+intc
plt.scatter(grouped_df_min_3["covid_cases_%"], grouped_df_min_3["vaccinated_pop_%"])
plt.plot(grouped_df_min_3["covid_cases_%"], model, color='red')
print(str("r value: ") + str(r.round(2)))
print(str("p value: ")+ str(p.round(2)))
print("regression equation: y="+str(slope.round(2))+"*x+"+str(intc.round(2)))
plt.xlabel("Covid Cases (%)")
plt.ylabel("Vaccinated Population (%)")
plt.savefig("covid_vaccination_regression_correct.png")
# Out:
# r value: -0.33
# p value: 0.02
# regression equation: y=-0.74*x+87.98

# %%
grouped_df_min_3
# Out:
#    state  population  total cases  vaccination completed  covid_cases_%  \
# 1     AL     4903185      1658639              2417598.0          33.83
# 10    GA    10617423      2976769              5382631.0          28.04
# 52    WY      578759       186790               298463.0          32.27
# 2     AR     3017804       994317              1584830.0          32.95
# 26    MS     2976149       997551              1570078.0          33.52
# 18    LA     4648794      1597940              2481895.0          34.37
# 24    MO     6137428      1788935              3318688.0          29.15
# 29    ND      762062       290693               415832.0          38.15
# 44    TN     6829174      2431986              3764812.0          35.61
# 13    ID     1787065       525855               989251.0          29.43
# 27    MT     1068778       333772               595007.0          31.23
# 42    SC     5148714      1850691              2870703.0          35.94
# 17    KY     4467673      1687705              2511980.0          37.78
# 37    OK     3956971      1305010              2251525.0          32.98
# 15    IN     6732219      2074640              3839173.0          30.82
# 51    WV     1792147       650365              1040252.0          36.29
# 22    MI     9986857      3050903              5878465.0          30.55
# 28    NC    10488084      3499262              6259639.0          33.36
# 36    OH    11689100      3438480              6991342.0          29.42
# 16    KS     2913314       946146              1760315.0          32.48
# 30    NE     1934408       574895              1170294.0          29.72
# 34    NV     3080156       886402              1869215.0          28.78
# 33    NM     2096829       673119              1290177.0          32.10
# 45    TX    28995881      8391808             18195398.0          28.94
# 12    IA     3155070       908961              1981880.0          28.81
# 0     AK      731545       297407               464153.0          40.65
# 3     AZ     7278717      2471556              4668433.0          33.96
# 43    SD      884659       282698               568286.0          31.96
# 46    UT     3205958      1088025              2096319.0          33.94
# 50    WI     5822434      2029197              3850570.0          34.85
# 39    PA    12801989      3555671              8516601.0          27.77
# 23    MN     5639632      1793774              3866285.0          31.81
# 9     FL    21477737      7542549             14758039.0          35.12
# 14    IL    12671821      4135817              8846776.0          32.64
# 8     DE      973764       332343               689007.0          34.13
# 38    OR     4217737       974929              2995706.0          23.11
# 5     CO     5758736      1784789              4121965.0          30.99
# 47    VA     8535519      2312297              6118287.0          27.09
# 4     CA    39512223     12240589             28724394.0          30.98
# 49    WA     7614893      1952979              5582876.0          25.65
# 32    NJ     8882190      3072027              6630856.0          34.59
# 19    MA     6892503      2027664              5224558.0          29.42
# 11    HI     1415872       376058              1091387.0          26.56
# 41    RI     1059361       426947               820172.0          40.30
# 20    MD     6045680      1378226              4749139.0          22.80
# 35    NY    19453561      6842910             15371326.0          35.18
# 48    VT      623989       150625               494523.0          24.14
# 40    PR     3193694      1091813              2557906.0          34.19
# 21    ME     1344212       322719              1080782.0          24.01
# 6     CT     3565287       975866              2912975.0          27.37
#
#     vaccinated_pop_%
# 1              49.31
# 10             50.70
# 52             51.57
# 2              52.52
# 26             52.76
# 18             53.39
# 24             54.07
# 29             54.57
# 44             55.13
# 13             55.36
# 27             55.67
# 42             55.76
# 17             56.23
# 37             56.90
# 15             57.03
# 51             58.05
# 22             58.86
# 28             59.68
# 36             59.81
# 16             60.42
# 30             60.50
# 34             60.69
# 33             61.53
# 45             62.75
# 12             62.82
# 0              63.45
# 3              64.14
# 43             64.24
# 46             65.39
# 50             66.13
# 39             66.53
# 23             68.56
# 9              68.71
# 14             69.81
# 8              70.76
# 38             71.03
# 5              71.58
# 47             71.68
# 4              72.70
# 49             73.32
# 32             74.65
# 19             75.80
# 11             77.08
# 41             77.42
# 20             78.55
# 35             79.02
# 48             79.25
# 40             80.09
# 21             80.40
# 6              81.70

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Vacination rate outlier boxplot')
ax1.set_ylabel('Vacination rate %')
ax1.boxplot(grouped_df['vaccinated_pop_%'])
plt.show()
fig1.savefig("vaccination_boxplot.png")

# %%
'''
fig1, ax1 = plt.subplots()
ax1.set_title('Covid cases outlier boxplot')
ax1.set_ylabel('Covid cases %')
ax1.boxplot(grouped_df['covid_cases_%'])
plt.show()

fig1, ax1 = plt.subplots()
ax1.set_title('Covid cases outlier boxplot')
ax1.set_ylabel('Covid cases %')
ax1.boxplot(grouped_df_min_3['covid_cases_%'])
plt.show()
'''
# Out:
# "\nfig1, ax1 = plt.subplots()\nax1.set_title('Covid cases outlier boxplot')\nax1.set_ylabel('Covid cases %')\nax1.boxplot(grouped_df['covid_cases_%'])\nplt.show()\n\nfig1, ax1 = plt.subplots()\nax1.set_title('Covid cases outlier boxplot')\nax1.set_ylabel('Covid cases %')\nax1.boxplot(grouped_df_min_3['covid_cases_%'])\nplt.show()\n"

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Covid cases outlier boxplot')
ax1.set_ylabel('Covid cases %')
ax1.boxplot(grouped_df['covid_cases_%'])
plt.show()
fig1.savefig("covid_cases_boxplot.png")

# %%
grouped_df_min_3

# %%
#Q2 Which states have the highest vaccination and infection rates?

top_5_states_covid = grouped_df_min_3.nlargest(5, ['covid_cases_%'])
bottom_5_states_covid = grouped_df_min_3.nsmallest(5, ['covid_cases_%'])
top_5_states_covid = top_5_states_covid.sort_values(by=['covid_cases_%'], ascending=True)
bottom_5_states_covid = bottom_5_states_covid.sort_values(by=['covid_cases_%'], ascending=True)

top_5_states_vaccination = grouped_df_min_3.nlargest(5, ['vaccinated_pop_%'])
bottom_5_states_vaccination = grouped_df_min_3.nsmallest(5, ['vaccinated_pop_%'])
top_5_states_vaccination = top_5_states_vaccination.sort_values(by=['vaccinated_pop_%'], ascending=True)
bottom_5_states_vaccination = bottom_5_states_vaccination.sort_values(by=['vaccinated_pop_%'], ascending=True)

top_5_states_covid['state_ex'] = 'Top' + ' ' + top_5_states_covid['state']
bottom_5_states_covid['state_ex'] = 'Bottom' + ' ' + bottom_5_states_covid['state']

top_5_states_vaccination['state_ex'] = 'Top' + ' ' + top_5_states_vaccination['state']
bottom_5_states_vaccination['state_ex'] = 'Bottom' + ' ' + bottom_5_states_vaccination['state']

df_concat_co = pd.concat([bottom_5_states_covid, top_5_states_covid], axis=0)
df_concat_va = pd.concat([bottom_5_states_vaccination, top_5_states_vaccination], axis=0)

# %%
df_concat_co.plot.bar(x="state_ex", y=['covid_cases_%','vaccinated_pop_%'], rot=70, title="The top and button 5 states in terms of Covid cases");
plot.set_ylabel('Covid cases %')
plt.savefig("Covid_cases_bar_chart.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 2
#       1 df_concat_co.plot.bar(x="state_ex", y=['covid_cases_%','vaccinated_pop_%'], rot=70, title="The top and button 5 states in terms of Covid cases");
# ----> 2 plot.set_ylabel('Covid cases %')
#       3 plt.savefig("Covid_cases_bar_chart.png")
#
# NameError: name 'plot' is not defined

# %%
df_concat_va.plot.bar(x="state_ex", y=['vaccinated_pop_%','covid_cases_%'], rot=70, title="The top and button 5 states in terms of Vacination Rates");
plt.savefig("Vacination_rates_bar_chart.png")
